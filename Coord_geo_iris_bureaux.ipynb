# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 994 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 77 kB/s
# ...
#      |████████████████████████████████| 6.6 MB 37.7 MB/s
# ...

# %%
pd.set_option("display.max_row",130)

# %%
import geopandas
from pyproj import Proj, transform

# %%
test = geopandas.read_file("/content/drive/MyDrive/test/test_17_08_2021.shp") # test_17_08_2021

# %%
geoiris = geopandas.read_file("/content/drive/MyDrive/test/iris_coord_2.shp")
geoiris # geoiris["DCOMIRIS"]
# Out:
#        DEPCOM  ...                                           geometry
# 0       97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 1       97202  ...  POLYGON ((-61.07379 14.54041, -61.07337 14.538...
# 2       97203  ...  POLYGON ((-61.08307 14.85248, -61.08441 14.850...
# 3       97204  ...  POLYGON ((-61.15649 14.73308, -61.15488 14.733...
# 4       97205  ...  POLYGON ((-61.12423 14.69021, -61.12086 14.689...
# ...       ...  ...                                                ...
# 508975  86194  ...  POLYGON ((0.31719 46.59390, 0.31732 46.59402, ...
# 508976  86194  ...  POLYGON ((0.31619 46.59271, 0.31612 46.59260, ...
# 508977  86194  ...  POLYGON ((0.32632 46.58821, 0.32617 46.58827, ...
# 508978  86177  ...  POLYGON ((0.24921 46.70597, 0.25172 46.70357, ...
# 508979  86157  ...  POLYGON ((0.39669 46.57734, 0.39763 46.57762, ...
#
# [508980 rows x 10 columns]

# %%
geoiris['DCOMIRIS'].value_counts()
# Out:
# 027490000    10
# 142130000    10
# 512900000    10
# 132100104    10
# 130410101    10
#              ..
# 593680301    10
# 471640000    10
# 576960000    10
# 751114409    10
# 763860000    10
# Name: DCOMIRIS, Length: 50898, dtype: int64

# %%
(geoiris['DCOMIRIS'].value_counts()>1).sum()
# Out:
# 50898

# %%
(geoiris['DCOMIRIS'].value_counts()-1).sum()
# Out:
# 458082

# %%
508980-458082
# Out:
# 50898

# %%
geoiris[geoiris["DCOMIRIS"]=="972010000"] ### -61.123497, 14.813882
# Out:
#        DEPCOM  ...                                           geometry
# 0       97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 50898   97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 101796  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 152694  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 203592  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 254490  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 305388  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 356286  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 407184  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
# 458082  97201  ...  POLYGON ((-61.09797 14.83121, -61.09867 14.830...
#
# [10 rows x 10 columns]

# %%
test[test["CODE_IRIS"]=="972010000"]
# Out:
#       INSEE_COM  ...                                           geometry
# 48817     97201  ...  POLYGON ((-6362643.029 5955966.681, -6362647.1...
#
# [1 rows x 10 columns]

# %%
test[test["CODE_IRIS"]=="972010000"]["geometry"]
# Out:
# 48817    POLYGON ((-6362643.029 5955966.681, -6362647.1...
# Name: geometry, dtype: geometry

# %%
inProj = Proj(init='epsg:2154') # RGF93
outProj = Proj(init='epsg:4326')
x1,y1 = -6362643.029, 5955966.681 
x2,y2 = transform(inProj,outProj,x1,y1)
print(x2,y2)
# Out:
# -61.09922846505095 14.81532297360991
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:306: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ...

# %%
-61.09922846505095 14.81532297360991 #-61.09797 14.83121 #-61,099228514,8153230
# Out:
#   File "<ipython-input-11-54902a38b64c>", line 1
#     -61.09922846505095 14.81532297360991 #-61.09797 14.83121 #-61,099228514,8153230
#                                        ^
# SyntaxError: invalid syntax

# %%
geoiris_lambert = geopandas.read_file("/content/drive/MyDrive/test/coord_lambert_wgs84/contours_iris_centroides_2019_lambert.shp")
geoiris_wgs84 = geopandas.read_file("/content/drive/MyDrive/test/coord_lambert_wgs84/contours_iris_centroides_2019_wgs84.shp")

# %%
geoiris_lambert.iloc[:2,:]
# Out:
#   INSEE_COM  ...                                           geometry
# 0     72191  ...  POLYGON ((497887.400 6747662.400, 497907.200 6...
# 1     77248  ...  POLYGON ((685757.700 6868592.300, 685832.500 6...
#
# [2 rows x 11 columns]

# %%
geoiris_wgs84.iloc[:2,:]
# Out:
#   INSEE_COM  ...                                           geometry
# 0     72191  ...  POLYGON ((0.29973 47.79825, 0.29999 47.79822, ...
# 1     77248  ...  POLYGON ((2.80567 48.91716, 2.80670 48.91471, ...
#
# [2 rows x 11 columns]

# %%
 
 geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"].iloc[:2,:]
# Out:
#     INSEE_COM  ...                                           geometry
# 191     59350  ...  POLYGON ((704878.400 7059147.300, 704887.300 7...
# 404     59350  ...  POLYGON ((704339.600 7058350.000, 704342.700 7...
#
# [2 rows x 11 columns]

# %%
#geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"]["XCentroide"]

inProj = Proj(init='epsg:2154') # RGF93
outProj = Proj(init='epsg:4326')
for i in range(len(geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"]["XCentroide"])):

    x1,y1 = geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"].iloc[i,8], geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"].iloc[i,9]
    x2,y2 = transform(inProj,outProj,x1,y1)
    print(x2,y2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:306: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ...

# %%
geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"].iloc[0,8], geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"].iloc[0,9]
# Out:
# (705228.2423927, 7059119.195488)

# %%
data_iris_centroides = geoiris_wgs84[["INSEE_COM","NOM_COM","IRIS","CODE_IRIS","NOM_IRIS","XCentroide","YCentroide"]]
data_iris_centroides["XCentroide"] = data_iris_centroides["XCentroide"].astype(float)
data_iris_centroides["YCentroide"] = data_iris_centroides["YCentroide"].astype(float)
data_iris_centroides
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       INSEE_COM                  NOM_COM  ... XCentroide YCentroide
# 0         72191                    Mayet  ...   0.279697  47.764499
# ...

# %%
###############################################   BUREAUX DE VOTES           ######################################################

#data = pd.read_csv("/content/drive/MyDrive/test/geo_bureaux_de_vote_clean.csv", header = 0, low_memory=False, dtype=str, error_bad_lines=False, encoding="ISO-8859-1" )


data=pd.read_csv("/content/drive/MyDrive/test/geo_bureaux_de_vote_clean.csv",sep=";", header = 0, low_memory=False, dtype=str, encoding="ISO-8859-1")
data.head(3)
# Out:
#   commune_code      libelle  ...                          geo_l4 geo_l5
# 0        59350        Lille  ...                      RUE D IENA    NaN
# 1        63058       Bulhon  ...                             NaN    NaN
# 2        97401  Les Avirons  ...  61 AVENUE DU GENERAL DE GAULLE    NaN
#
# [3 rows x 22 columns]

# %%
data[data["commune_code"]=="59350"][data[data["commune_code"]=="59350"]["voie"]=="RUE D'IENA"]
# Out:
#      commune_code libelle code  ... geo_ligne      geo_l4 geo_l5
# 0           59350   Lille  807  ...         G  RUE D IENA    NaN
# 9190        59350   Lille  809  ...         G  RUE D IENA    NaN
#
# [2 rows x 22 columns]

# %%
data[data["commune_code"]=="59350"]
# Out:
#       commune_code libelle  ...                           geo_l4 geo_l5
# 0            59350   Lille  ...                       RUE D IENA    NaN
# 714          59350   Lille  ...                    8 RUE DE TOUL    NaN
# 1185         59350   Lille  ...                 46 RUE LEON BLUM    NaN
# 3727         59350   Lille  ...                   20 RUE DU PORT    NaN
# 3812         59350   Lille  ...       257 AVENUE ARTHUR NOTEBART    NaN
# 4001         59350   Lille  ...                    RUE LAMARTINE  LILLE
# 4022         59350   Lille  ...           PLACE AUGUSTIN LAURENT    NaN
# 5077         59350   Lille  ...               RUE ANATOLE FRANCE  LILLE
# 5418         59350   Lille  ...        133 BOULEVARD VICTOR HUGO    NaN
# 5815         59350   Lille  ...         RUE DU LIEUTENANT COLPIN    NaN
# 7933         59350   Lille  ...                    RUE LAMARTINE  LILLE
# 8140         59350   Lille  ...                 1 RUE EMILE ZOLA    NaN
# ...

# %%
len(geoiris_lambert[geoiris_lambert["INSEE_COM"]=="59350"]["XCentroide"])
# Out:
# 110

# %%
data[data["geo_score"]!="0"]
# Out:
#       commune_code  ... geo_l5
# 0            59350  ...    NaN
# 2            97401  ...    NaN
# 5            50502  ...    NaN
# 7            97411  ...    NaN
# 10           56121  ...    NaN
# ...            ...  ...    ...
# 70037         2810  ...    NaN
# 70038        25040  ...    NaN
# 70039        14563  ...    NaN
# 70040        97109  ...    NaN
# 70041        97109  ...    NaN
#
# [60990 rows x 22 columns]

# %%
new_data_votes = data[data["geo_score"]!="0"].drop_duplicates(subset =["longitude","latitude"], keep = 'first')#,"geo_l4"
new_data_votes["longitude"] = new_data_votes["longitude"].astype(float)
new_data_votes["latitude"] = new_data_votes["latitude"].astype(float)
new_data_votes
# Out:
#       commune_code  ... geo_l5
# 0            59350  ...    NaN
# 2            97401  ...    NaN
# 5            50502  ...    NaN
# 7            97411  ...    NaN
# 10           56121  ...    NaN
# ...            ...  ...    ...
# 70032        97616  ...    NaN
# 70033        97616  ...    NaN
# 70038        25040  ...    NaN
# 70039        14563  ...    NaN
# 70040        97109  ...    NaN
#
# [47354 rows x 22 columns]

# %%
# enregistrement des bureaux de votes sans doublons
#new_data_votes.to_csv("/content/drive/MyDrive/test/new_data_votes.csv", sep=";", index =False , header = 0)

# %%
pd.DataFrame(columns=new_data_votes.columns)
# Out:
# Empty DataFrame
# Columns: [commune_code, libelle, code, libelle.1, num_voie, voie, complement1, complement2, lieu_dit, code_postal, commune, canton_code, circonscription_code, longitude, latitude, geo_score, geo_type, geo_adresse, geo_id, geo_ligne, geo_l4, geo_l5]
# Index: []

# %%
data_iris_votes =pd.concat([new_data_votes, pd.DataFrame(columns=new_data_votes.columns)],axis=1)
data_iris_votes["longitude"] = data_iris_votes["longitude"].astype(float)
data_iris_votes["latitude"] = data_iris_votes["latitude"].astype(float)
data_iris_votes
# Out:
#       commune_code                    libelle code  ... geo_ligne geo_l4 geo_l5
# 0            59350                      Lille  807  ...       NaN    NaN    NaN
# 2            97401                Les Avirons    1  ...       NaN    NaN    NaN
# 5            50502                  Saint-LÃ´    8  ...       NaN    NaN    NaN
# 7            97411                Saint-Denis  118  ...       NaN    NaN    NaN
# 10           56121                    Lorient   11  ...       NaN    NaN    NaN
# ...            ...                        ...  ...  ...       ...    ...    ...
# 70032        97616                       Sada   83  ...       NaN    NaN    NaN
# 70033        97616                       Sada  129  ...       NaN    NaN    NaN
# 70038        25040                    Badevel    1  ...       NaN    NaN    NaN
# 70039        14563  Saint-BenoÃ®t-d'HÃ©bertot    1  ...       NaN    NaN    NaN
# 70040        97109                  Gourbeyre    4  ...       NaN    NaN    NaN
#
# ...

# %%
#data_iris_votes #data_iris_centroides

data_iris_votes.iloc[:,13:15], data_iris_centroides.iloc[:,5:7]
# Out:
# (       longitude   latitude
#  0       3.043027  50.621124
#  2      55.333200 -21.242358
#  5      -1.074428  49.117378
#  7      55.483666 -20.893953
#  10     -3.368220  47.744513
#  ...          ...        ...
#  70032  45.093095 -12.851659
#  70033  45.108125 -12.845941
#  70038   6.939282  47.500913
#  70039   0.270550  49.316366
#  70040 -61.709542  15.991323
#
#  [47424 rows x 2 columns],        XCentroide  YCentroide
#  0        0.279697   47.764499
#  1        2.792871   48.915337
#  2        3.779018   48.736126
#  3        2.365133   44.044992
#  4        3.908037   50.286193
#  ...           ...         ...
#  49399  -52.331478    4.798375
#  49400  -54.024326    5.504101
#  49401  -52.371961    4.869775
#  49402  -54.035501    4.042806
#  49403  -54.269953    4.829841
#
#  [49404 rows x 2 columns])

# %%
data_iris_centroides.iloc[0,5:7].values,data_iris_votes.iloc[0,13:15].values
# Out:
# (array([0.2796965, 47.76449925], dtype=object),
#  array([3.043027, 50.621124], dtype=object))

# %%
a=data_iris_centroides.iloc[0,5:7].values
b=data_iris_votes.iloc[0,13:15].values
dist = np.linalg.norm(a-b)
dist
# Out:
# 3.974455989760463

# %%
k=0
for i in range(data_iris_centroides.shape[0]):
    for j in range(data_iris_votes.shape[0]):
# Out:
#   File "<ipython-input-43-485fffe0add5>", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
data_iris_votes

# %%
data[data["geo_score"]!="0"].shape[0] - data[data["geo_score"]!="0"].drop_duplicates(keep = 'first').shape[0]
# Out:
# 2

# %%
data_iris_centroides[data_iris_centroides["INSEE_COM"]==data_iris_centroides["INSEE_COM"].value_counts().index[0]]
# Out:
#       INSEE_COM   NOM_COM  IRIS  ...          NOM_IRIS XCentroide  YCentroide
# 164       31555  Toulouse  4004  ...             Nicol   1.467254   43.634332
# 902       31555  Toulouse  0501  ...         Filatiers   1.443283   43.599054
# 905       31555  Toulouse  3201  ...            Morvan   1.407865   43.580410
# 1201      31555  Toulouse  2102  ...        Providence   1.465407   43.603140
# 1394      31555  Toulouse  1302  ...        Saint-Léon   1.445546   43.586934
# ...         ...       ...   ...  ...               ...        ...         ...
# 46499     31555  Toulouse  1103  ...      Gabriel Péri   1.453605   43.606680
# 47063     31555  Toulouse  1807  ...         Negreneys   1.442023   43.617918
# 47625     31555  Toulouse  2202  ...  Coin de la Moure   1.468371   43.595852
# 47855     31555  Toulouse  5801  ...        Sauvegrain   1.384787   43.588151
# 48407     31555  Toulouse  1702  ...           Troenes   1.413052   43.619360
#
# [153 rows x 7 columns]

# %%
new_data_votes[new_data_votes["commune_code"]==data_iris_centroides["INSEE_COM"].value_counts().index[0]].shape
# Out:
# (67, 22)

# %%
data_iris_centroides["INSEE_COM"].value_counts().index[0]
# Out:
# '31555'

# %%
(data_iris_votes["commune_code"]==data_iris_centroides["INSEE_COM"].value_counts().index[0])
# Out:
#        commune_code  commune_code
# 0             False         False
# 2             False         False
# 5             False         False
# 7             False         False
# 10            False         False
# ...             ...           ...
# 70032         False         False
# 70033         False         False
# 70038         False         False
# 70039         False         False
# 70040         False         False
#
# [47424 rows x 2 columns]

# %%
data_iris_votes
# Out:
#       commune_code                    libelle code  ... geo_ligne geo_l4 geo_l5
# 0            59350                      Lille  807  ...       NaN    NaN    NaN
# 2            97401                Les Avirons    1  ...       NaN    NaN    NaN
# 5            50502                  Saint-LÃ´    8  ...       NaN    NaN    NaN
# 7            97411                Saint-Denis  118  ...       NaN    NaN    NaN
# 10           56121                    Lorient   11  ...       NaN    NaN    NaN
# ...            ...                        ...  ...  ...       ...    ...    ...
# 70032        97616                       Sada   83  ...       NaN    NaN    NaN
# 70033        97616                       Sada  129  ...       NaN    NaN    NaN
# 70038        25040                    Badevel    1  ...       NaN    NaN    NaN
# 70039        14563  Saint-BenoÃ®t-d'HÃ©bertot    1  ...       NaN    NaN    NaN
# 70040        97109                  Gourbeyre    4  ...       NaN    NaN    NaN
#
# ...
